# %% [markdown]
# Importing Necessary Packages

# %%
import numpy as np
import pandas as pd


import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)

plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('Solarize_Light2')

# %% [markdown]
# Uploading Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/Dataset/bank-direct-marketing-campaigns.csv'

data = pd.read_csv(file_path, header = 0)

# %% [markdown]
# Examining The Data

# %%
print('Shape of the dataset:', data.shape)
# Out:
# Shape of the dataset: (41188, 20)

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
data.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  campaign  pdays  previous     poutcome  \
# 41183  cellular   nov         fri         1    999         0  nonexistent
# 41184  cellular   nov         fri         1    999         0  nonexistent
# 41185  cellular   nov         fri         2    999         0  nonexistent
# 41186  cellular   nov         fri         1    999         0  nonexistent
# 41187  cellular   nov         fri         3    999         1      failure
#
# ...

# %%
data.sample(n = 10)
# Out:
#        age          job  marital          education  default housing loan  \
# 4734    36   technician  married  university.degree       no      no   no
# 37899   28   management   single  university.degree       no     yes   no
# 35349   32  blue-collar   single           basic.9y       no     yes   no
# 20752   44  blue-collar  married           basic.4y  unknown     yes  yes
# 12209   49   technician   single        high.school       no     yes   no
# 30298   28       admin.   single  university.degree       no     yes   no
# 16503   38  blue-collar  married        high.school       no     yes   no
# 12871   37       admin.  married  university.degree       no      no   no
# 4276    45  blue-collar  married           basic.4y  unknown     yes   no
# 9081    35       admin.  married  university.degree       no     yes   no
#
#          contact month day_of_week  campaign  pdays  previous     poutcome  \
# 4734   telephone   may         wed         1    999         0  nonexistent
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  campaign        41188 non-null  int64
#  11  pdays           41188 non-null  int64
#  12  previous        41188 non-null  int64
#  13  poutcome        41188 non-null  object
#  14  emp.var.rate    41188 non-null  float64
#  15  cons.price.idx  41188 non-null  float64
#  16  cons.conf.idx   41188 non-null  float64
# ...

# %% [markdown]
# Descriptive Statastics

# %%
data.describe().style.background_gradient(cmap = 'copper')
# Out:
# <style type="text/css">
# #T_8db31_row0_col0, #T_8db31_row0_col1, #T_8db31_row0_col2, #T_8db31_row0_col3, #T_8db31_row0_col4, #T_8db31_row0_col5, #T_8db31_row0_col6, #T_8db31_row0_col7, #T_8db31_row0_col8 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# ...

# %%
data.describe(include = 'object')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %%
plt.rcParams['figure.figsize'] = (10, 5)
plt.style.use('Solarize_Light2')

plt.subplot(1, 2, 1)
sns.countplot(x = data['y'])

plt.xlabel('Subscribed or Not?', fontsize = 10)

plt.subplot(1, 2, 2)
data['y'].value_counts().plot(kind = 'pie', explode = [0, 0.1], autopct = '%.2f%%', startangle = 90,
                                       labels = ['1','0'], shadow = True, pctdistance = 0.5)
plt.axis('off')

plt.suptitle('Target Class Balance', fontsize = 15)
plt.show()

# %% [markdown]
# Treating Missing Values

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# Feature Engineering

# %%
# Renaming a single column
data.rename(columns={'emp.var.rate': 'emp_var_rate',
                     'cons.price.idx':'cons_price_idx',
                     'cons.conf.idx':'cons_conf_idx',
                     'nr.employed':'nr_employed',
                     'y':'target'
                     }
                    ,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  campaign        41188 non-null  int64
#  11  pdays           41188 non-null  int64
#  12  previous        41188 non-null  int64
#  13  poutcome        41188 non-null  object
#  14  emp_var_rate    41188 non-null  float64
#  15  cons_price_idx  41188 non-null  float64
#  16  cons_conf_idx   41188 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx',
#        'euribor3m', 'nr_employed', 'target'],
#       dtype='object')

# %% [markdown]
# Removing Duuplicates

# %%
# Removing Duplicates
dup = data.duplicated()
print('Before removing duplicates: ',data.shape)
data = data.drop_duplicates()
print('After removing duplicates: ',data.shape)
# Out:
# Before removing duplicates:  (41188, 20)
# After removing duplicates:  (39404, 20)

# %%
#Resetting Index
data=data.reset_index(drop=True)
data_BK2=data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39404 entries, 0 to 39403
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             39404 non-null  int64
#  1   job             39404 non-null  object
#  2   marital         39404 non-null  object
#  3   education       39404 non-null  object
#  4   default         39404 non-null  object
#  5   housing         39404 non-null  object
#  6   loan            39404 non-null  object
#  7   contact         39404 non-null  object
#  8   month           39404 non-null  object
#  9   day_of_week     39404 non-null  object
#  10  campaign        39404 non-null  int64
#  11  pdays           39404 non-null  int64
#  12  previous        39404 non-null  int64
#  13  poutcome        39404 non-null  object
#  14  emp_var_rate    39404 non-null  float64
#  15  cons_price_idx  39404 non-null  float64
#  16  cons_conf_idx   39404 non-null  float64
# ...

# %% [markdown]
# Univariate Analysis

# %%
data.select_dtypes('number').head()
# Out:
#    age  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 0   56         1    999         0           1.1          93.994
# 1   57         1    999         0           1.1          93.994
# 2   37         1    999         0           1.1          93.994
# 3   40         1    999         0           1.1          93.994
# 4   56         1    999         0           1.1          93.994
#
#    cons_conf_idx  euribor3m  nr_employed
# 0          -36.4      4.857       5191.0
# 1          -36.4      4.857       5191.0
# 2          -36.4      4.857       5191.0
# 3          -36.4      4.857       5191.0
# 4          -36.4      4.857       5191.0

# %%
plt.rcParams['figure.figsize'] = (10, 5)
plt.style.use('Solarize_Light2')

plt.subplot(1, 2, 1)
sns.boxplot(x = data['cons_price_idx'], color = 'red')
plt.xlabel('Consumer Price Index', fontsize = 12)
plt.ylabel('Range', fontsize = 12)

plt.subplot(1, 2, 2)
sns.boxplot(x = data['cons_conf_idx'], color = 'red')
plt.xlabel('Length of Service', fontsize = 12)
plt.ylabel('Consumer Confidence Index', fontsize = 12)

plt.suptitle('Box Plot', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 4)
sns.countplot(x = data['campaign'], palette = 'spring')
plt.xlabel(' ', fontsize = 14)
plt.title('Distribution of Meetings undertaken by the Subscribers')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (16,5)
plt.style.use('Solarize_Light2')

plt.subplot(1, 3, 1)
labels = data['education'].value_counts().index
sizes = data['education'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0, 0.1]

plt.pie(sizes, labels = labels, colors = colors, shadow = True, startangle = 90)
plt.title('Education', fontsize = 20)


plt.subplot(1, 3, 2)
labels = data['loan'].value_counts().index
sizes = data['loan'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0, 0.1]

plt.pie(sizes, labels = labels, colors = colors, shadow = True, startangle = 90)
plt.title('Loan', fontsize = 20)

plt.subplot(1, 3, 3)
labels = data['housing'].value_counts().index
sizes = data['housing'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0,0.1,0.2]

plt.pie(sizes, labels = labels, colors = colors, shadow = True, startangle = 90)
plt.title('Housing', fontsize = 20)

plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
plt.rcParams['figure.figsize'] = (10, 3)
x = pd.crosstab(data['loan'], data['target'])
colors = plt.cm.Wistia(np.linspace(0, 1, 5))
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = False)
plt.title('Effect of Loan on Subscription', fontsize = 15)
plt.xlabel(' ')
plt.show()

# %% [markdown]
# Multi-Variate Analysis

# %%
plt.rcParams['figure.figsize'] = (15, 10)
plt.style.use('fivethirtyeight')

sns.heatmap(data.corr(), annot = True, linewidth = 0.5, cmap = 'viridis')
plt.title('Correlation Heat Map', fontsize = 15)
plt.show()

# %% [markdown]
# Dealing with categorical Columns

# %%
data.select_dtypes('object').head()
# Out:
#          job  marital    education  default housing loan    contact month  \
# 0  housemaid  married     basic.4y       no      no   no  telephone   may
# 1   services  married  high.school  unknown      no   no  telephone   may
# 2   services  married  high.school       no     yes   no  telephone   may
# 3     admin.  married     basic.6y       no      no   no  telephone   may
# 4   services  married  high.school       no      no  yes  telephone   may
#
#   day_of_week     poutcome target
# 0         mon  nonexistent     no
# 1         mon  nonexistent     no
# 2         mon  nonexistent     no
# 3         mon  nonexistent     no
# 4         mon  nonexistent     no

# %%
data.job.value_counts()
# Out:
# admin.           9873
# blue-collar      8835
# technician       6404
# services         3801
# management       2820
# retired          1683
# entrepreneur     1405
# self-employed    1386
# housemaid        1028
# unemployed        992
# student           852
# unknown           325
# Name: job, dtype: int64

# %%
data.day_of_week.value_counts()
# Out:
# thu    8197
# mon    8188
# wed    7760
# tue    7708
# fri    7551
# Name: day_of_week, dtype: int64

# %%
#converting object data into numerical data using labelencoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['job'] = le.fit_transform(data['job'])
data['marital'] = le.fit_transform(data['marital'])
data['education'] = le.fit_transform(data['education'])
data['month'] = le.fit_transform(data['month'])
data['contact'] = le.fit_transform(data['contact'])
data['poutcome'] = le.fit_transform(data['poutcome'])
data['day_of_week'] = le.fit_transform(data['day_of_week'])

# %%
data.loan.value_counts()
# Out:
# no         32248
# yes         6176
# unknown      980
# Name: loan, dtype: int64

# %%
data.housing.value_counts()
# Out:
# yes        20561
# no         17863
# unknown      980
# Name: housing, dtype: int64

# %%
# Mapping of categorical values to numerical format
mapping = {
    'yes': 1,
    'no': 0,
    'unknown': -1
}

# Replace the categorical values with numerical format
data['default'] = data['default'].replace(mapping)
data['housing'] = data['housing'].replace(mapping)
data['loan'] = data['loan'].replace(mapping)
data['target'] = data['target'].replace(mapping)

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3       -1        0     0        1      6
# 2   37    7        1          3        0        1     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     1        1      6
#
#    day_of_week  campaign  pdays  previous  poutcome  emp_var_rate  \
# 0            1         1    999         0         1           1.1
# 1            1         1    999         0         1           1.1
# 2            1         1    999         0         1           1.1
# 3            1         1    999         0         1           1.1
# 4            1         1    999         0         1           1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed  target
# 0          93.994          -36.4      4.857       5191.0       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39404 entries, 0 to 39403
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             39404 non-null  int64
#  1   job             39404 non-null  int64
#  2   marital         39404 non-null  int64
#  3   education       39404 non-null  int64
#  4   default         39404 non-null  int64
#  5   housing         39404 non-null  int64
#  6   loan            39404 non-null  int64
#  7   contact         39404 non-null  int64
#  8   month           39404 non-null  int64
#  9   day_of_week     39404 non-null  int64
#  10  campaign        39404 non-null  int64
#  11  pdays           39404 non-null  int64
#  12  previous        39404 non-null  int64
#  13  poutcome        39404 non-null  int64
#  14  emp_var_rate    39404 non-null  float64
#  15  cons_price_idx  39404 non-null  float64
#  16  cons_conf_idx   39404 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx',
#        'euribor3m', 'nr_employed', 'target'],
#       dtype='object')

# %%
print(data.select_dtypes('object').columns)
# Out:
# Index([], dtype='object')

# %% [markdown]
# Splitting the test and train data

# %%
x = data.drop(['target'], axis = 1)
y = data['target']

print("Shape of the x :", x.shape)
print("Shape of the y :", y.shape)
# Out:
# Shape of the x : (39404, 19)
# Shape of the y : (39404,)

# %% [markdown]
# Oversampling

# %%
from imblearn.over_sampling import SMOTE

x_resample, y_resample  = SMOTE().fit_resample(x, y.values.ravel())

print(x_resample.shape)
print(y_resample.shape)
# Out:
# (69612, 19)
# (69612,)

# %%
print("Before Resampling :")
print(y.value_counts())

y_resample = pd.DataFrame(y_resample)

print("After Resampling :")
print(y_resample[0].value_counts())
# Out:
# Before Resampling :
# 0    34806
# 1     4598
# Name: target, dtype: int64
# After Resampling :
# 0    34806
# 1    34806
# Name: 0, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_resample, y_resample, test_size = 0.2, random_state = 42)

# %%
print("Shape of the x test :", x_test.shape)
print("Shape of the x train :", x_train.shape)
print("Shape of the y test :", y_test.shape)
print("Shape of the y train :", y_train.shape)
# Out:
# Shape of the x test : (13923, 19)
# Shape of the x train : (55689, 19)
# Shape of the y test : (13923, 1)
# Shape of the y train : (55689, 1)

# %% [markdown]
# Random Forest Algorithm

# %%
# to buildthe 'random forest' model with random sampling
from sklearn.ensemble import RandomForestClassifier

#building the model
model = RandomForestClassifier()
model.fit(x_train,y_train)

#predicting
y_pred = model.predict(x_test)
y_pred_prob = model.predict_proba(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

print("Training Accuracy :", model.score(x_train, y_train)*100, '%')
print("Testing Accuracy :", model.score(x_test, y_test)*100, '%')

cm = confusion_matrix(y_test, y_pred)
plt.rcParams['figure.figsize'] = (3, 3)
sns.heatmap(cm, annot = True, cmap = 'inferno', fmt = '.8g')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
# Out:
# Training Accuracy : 99.63367990087809 %
# Testing Accuracy : 92.12813330460389 %

# %%
# Actual Values
actual = y_test

# Predicted values
predicted = y_pred

# Confusion matrix
matrix = confusion_matrix(actual,predicted, labels=[1,0], sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)
# Out:
# Confusion matrix :
#  [[6389  571]
#  [ 525 6438]]

# %%
tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)
# Out:
# Outcome values :
#  6389 571 525 6438

# %%
# Classification report for precision, recall f1-score and accuracy
C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.92      0.92      0.92      6960
#            0       0.92      0.92      0.92      6963
#
#     accuracy                           0.92     13923
#    macro avg       0.92      0.92      0.92     13923
# weighted avg       0.92      0.92      0.92     13923

# %%
# Calculating the metrics
sensitivity = round(tp/(tp+fn), 3)
specificity = round(tn/(tn+fp), 3)
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3)
balanced_accuracy = round((sensitivity+specificity)/2, 3)
precision = round(tp/(tp+fp), 3)
f1Score = round((2*tp/(2*tp + fp + fn)), 3)

# %%
from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2), '%')
print('Precision :', round(precision*100, 2), '%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%')
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)
# Out:
# Accuracy : 92.1 %
# Precision : 92.4 %
# Recall : 91.8 %
# F1 Score : 0.921
# Specificity or True Negative Rate : 92.5 %
# Balanced Accuracy : 92.2 %
# MCC : 0.843

# %%
#area under ROC curve
from sklearn.metrics import roc_curve, roc_auc_score
print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
# Out:
# roc_auc_score: 0.921

# %%
# ROC Curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual, model.predict_proba(x_test)[:,1])
plt.figure(figsize=(10, 7))
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize = 12)
plt.ylabel('True Positive Rate', fontsize = 12)
plt.title('Receiver operating characteristic', fontsize = 16)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Prediction

# %%
prediction = model.predict(np.array([[ 29,  #age
                                        1,  #job
                                        2,  #marital
                                        6,  #education
                                        0,  #default
                                        0,  #housing
                                        0,  #loan
                                        0,  #contact
                                        8,  #month
                                        1,  #day_of_week
                                        1,  #campaign
                                        999, #pdays
                                        0,  #previous
                                        1,  #poutcome
                                        -1, #emp_var_rate
                                        94.601, #cons_price_idx
                                        -49.5,  #cons_conf_idx
                                        0.997,  #euribor3m
                                        4963.6  #nr_employed
                                        ]]))

print('Whether the person will get Subscribe to the Term or not: ([0]->not sanctioned, [1]-> sanctioned)\nThe above prediction is:',prediction)
# Out:
# Whether the person will get Subscribe to the Term or not: ([0]->not sanctioned, [1]-> sanctioned)
# The above prediction is: [1]
